# %% [markdown]
# # L03 — IPC vs N for saxpy
#
# Sweep vector length N, run `pmu_saxpy` for each, parse cycles/instructions, plot IPC vs log2(N).
#
# **Expected shape:** IPC is high for small N (fits in L1d), drops at the L1 boundary, drops again at L2, plateaus at memory bandwidth limit.

# %%
# TODO
# import subprocess, json
# import numpy as np
# import matplotlib.pyplot as plt
#
# Ns = [2**k for k in range(8, 24)]
# rows = []
# for N in Ns:
#     out = subprocess.check_output(['./pmu_saxpy', str(N)], text=True)
#     # parse stdout  → cycles, instructions
#     ...
# plt.semilogx(Ns, ipcs, 'o-')
# plt.xlabel('N (elements)')
# plt.ylabel('IPC')
# plt.title('saxpy IPC vs working-set size')
# plt.show()
