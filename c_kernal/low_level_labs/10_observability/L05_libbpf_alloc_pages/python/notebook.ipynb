# %% [markdown]
# # L05 — page allocation orders during Cholesky
#
# Captures BCC histogram dumps for each N and plots the distribution. Look for the inflection point where order 9 (2 MiB folios) first appears.

# %%
# TODO
# import json
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Load captured histograms (one JSON per N, written by your bindings.py)
# data = {}
# for N in [64, 256, 1024, 4096, 8192]:
#     data[N] = json.load(open(f'../traces/hist_N{N}.json'))
#
# # Heatmap: rows=N, cols=order, color=count
# orders = sorted({o for h in data.values() for o in h})
# Z = np.array([[data[N].get(o, 0) for o in orders] for N in data])
# plt.imshow(Z, aspect='auto'); plt.xticks(range(len(orders)), orders); plt.yticks(range(len(data)), list(data))
# plt.xlabel('alloc order'); plt.ylabel('N')
# plt.colorbar(label='count'); plt.show()
