# %% [markdown]
# # L07 — NUMA bandwidth bar chart
#
# Run dot under three numactl configurations, plot GB/s, annotate cross-socket penalty.

# %%
# TODO
# from bindings import sweep
# import matplotlib.pyplot as plt
#
# r = sweep()
# plt.bar(r.keys(), r.values())
# plt.ylabel('GB/s'); plt.title('dot bandwidth across NUMA configs')
# plt.show()
# print('penalty (1 - remote/local):', 1 - r['remote']/r['local'])
