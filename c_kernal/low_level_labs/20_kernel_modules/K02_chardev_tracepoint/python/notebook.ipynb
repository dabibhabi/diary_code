# %% [markdown]
# # K02 — tracepoint cost measurement
#
# Compare /dev/nm_xorshift throughput with no observer, with bpftrace attached, and with the BCC reader running. Plot bar chart.

# %%
# TODO
# import subprocess, time
# import matplotlib.pyplot as plt
#
# def throughput_mb_s(seconds=3):
#     t0 = time.time()
#     # subprocess call to `pv` or `dd` for `seconds` s, capture bytes
#     ...
#
# results = {'unattached': throughput_mb_s(), 'bpftrace': ..., 'bcc': ...}
# plt.bar(results.keys(), results.values()); plt.ylabel('MB/s'); plt.show()
