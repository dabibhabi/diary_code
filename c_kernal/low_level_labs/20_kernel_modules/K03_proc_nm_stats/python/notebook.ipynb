# %% [markdown]
# # K03 — /proc/nm_stats per-CPU bar chart
#
# After stress-testing on multiple CPUs, plot bytes-per-CPU. Compare against `lscpu --extended` to see if NUMA grouping is visible.

# %%
# TODO
# import matplotlib.pyplot as plt
# from bindings import read_proc
#
# stats = read_proc()
# plt.bar([s.cpu for s in stats], [s.bytes for s in stats])
# plt.xlabel('CPU'); plt.ylabel('bytes'); plt.title('/dev/nm_xorshift: bytes per CPU'); plt.show()
