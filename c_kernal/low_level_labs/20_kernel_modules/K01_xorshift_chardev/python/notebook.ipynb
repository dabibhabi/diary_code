# %% [markdown]
# # K01 — kernel xorshift uniformity
#
# Read N bytes from /dev/nm_xorshift, run a chi-square test for byte-uniformity, plot histogram. Expected: chi-square p-value > 0.01 (we shouldn't reject uniformity).

# %%
# TODO
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import chisquare
# from bindings import KernelDevice
#
# data = np.frombuffer(KernelDevice().read(1 << 20), dtype=np.uint8)
# counts, _ = np.histogram(data, bins=256, range=(0, 256))
# stat, p = chisquare(counts)
# print(f'chi-square stat={stat:.2f}, p={p:.4f}')
# plt.bar(range(256), counts); plt.xlabel('byte value'); plt.ylabel('count'); plt.show()
