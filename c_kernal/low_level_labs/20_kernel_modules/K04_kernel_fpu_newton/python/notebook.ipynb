# %% [markdown]
# # K04 — fixed-point vs FP Newton: error and latency curves
#
# Sweep input across a range, plot relative error and per-call latency for both paths.

# %%
# TODO
# import math, time
# import numpy as np
# import matplotlib.pyplot as plt
# from bindings import kernel_sqrt_q32, kernel_sqrt_f64
#
# xs = np.logspace(-3, 10, 50)
# err_fx = []; err_fp = []; lat_fx = []; lat_fp = []
# for x in xs:
#     ref = math.sqrt(x)
#     t0 = time.perf_counter_ns(); r = kernel_sqrt_q32(int(x*(1<<32))); lat_fx.append(time.perf_counter_ns()-t0)
#     err_fx.append(abs(r/(1<<32) - ref) / ref)
#     t0 = time.perf_counter_ns(); r = kernel_sqrt_f64(x); lat_fp.append(time.perf_counter_ns()-t0)
#     err_fp.append(abs(r - ref) / ref)
#
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))
# ax1.loglog(xs, err_fx, 'o-', label='fixed-point'); ax1.loglog(xs, err_fp, 's-', label='FP')
# ax1.set_xlabel('x'); ax1.set_ylabel('rel err'); ax1.legend()
# ax2.loglog(xs, lat_fx, 'o-', label='fixed-point'); ax2.loglog(xs, lat_fp, 's-', label='FP')
# ax2.set_xlabel('x'); ax2.set_ylabel('latency (ns/call, includes ioctl)'); ax2.legend()
# plt.show()
