# %% [markdown]
# # B04 — PIT jitter distribution
#
# Plot the captured histogram, fit a normal (or log-normal) distribution, identify outliers.

# %%
# TODO
# import json, numpy as np, matplotlib.pyplot as plt
# from scipy.stats import norm
#
# h = {int(k): int(v) for k, v in json.load(open('histogram.json')).items()}
# bins, counts = zip(*sorted(h.items()))
# bins = np.array(bins); counts = np.array(counts)
# # crude reconstruction: each bin contributes `counts[i]` samples at value `bins[i]`
# samples = np.repeat(bins, counts)
# plt.hist(samples, bins=64); plt.xlabel('cycles per tick'); plt.title('PIT jitter')
# print('mean', samples.mean(), 'std', samples.std(), 'p99', np.percentile(samples, 99))
