# %% [markdown]
# # B02 — bare-metal Newton cycle distribution
#
# Run `cycles` 1000 times, plot histogram, compare with the same iteration in pinned userspace.

# %%
# TODO
# import numpy as np, matplotlib.pyplot as plt
# from bindings import connect, send
#
# s = connect()
# samples = []
# for _ in range(1000):
#     out = send(s, 'cycles')
#     for tok in out.split():
#         try: samples.append(int(tok)); break
#         except ValueError: pass
# plt.hist(samples, bins=80); plt.xlabel('cyc/op'); plt.title('bare-metal Newton'); plt.show()
# print('mean', np.mean(samples), 'p99', np.percentile(samples, 99))
