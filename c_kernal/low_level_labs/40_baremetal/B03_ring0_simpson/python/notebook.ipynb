# %% [markdown]
# # B03 — Simpson convergence
#
# Plot log-log error vs n; expect slope ≈ -4. Compare against the float-point implementation in `cpp/numerical_methods/src/quadrature/`.

# %%
# TODO
# import numpy as np, matplotlib.pyplot as plt
# from bindings import read_kernel_results, reference
#
# r = read_kernel_results(); ref = reference()
# ns = np.array(sorted(r))
# err = np.array([abs(r[n] - ref) for n in ns])
# plt.loglog(ns, err, 'o-'); plt.xlabel('n'); plt.ylabel('|err|')
# slope = np.polyfit(np.log(ns), np.log(err), 1)[0]
# plt.title(f'Simpson convergence; slope ≈ {slope:.2f}')
# plt.show()
