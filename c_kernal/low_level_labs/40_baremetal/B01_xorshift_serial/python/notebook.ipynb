# %% [markdown]
# # B01 — bare-metal xorshift uniformity
#
# Read 16 (or more — bump kernel loop) numbers from COM1, plot byte histogram, run chi-square.

# %%
# TODO
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import chisquare
# from bindings import read_kernel
#
# k = read_kernel(16)
# b = np.array(k, dtype=np.uint64).tobytes()
# data = np.frombuffer(b, dtype=np.uint8)
# hist, _ = np.histogram(data, bins=256, range=(0,256))
# stat, p = chisquare(hist)
# print('chi2', stat, 'p', p)
# plt.bar(range(256), hist); plt.title('byte distribution from bare-metal'); plt.show()
