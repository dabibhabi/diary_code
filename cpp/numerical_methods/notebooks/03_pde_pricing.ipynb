# %% [markdown]
# # 03 — PDE pricing: heat equation $\to$ Black-Scholes
#
# Black-Scholes reduces to the heat equation $u_t = \nu u_{xx}$ under a change of variables. We solve it on a grid with three schemes and compare to the closed-form
#
# $$ C = S_0\,\Phi(d_1) - K e^{-rT}\,\Phi(d_2). $$
#
# **Prerequisites**: `pde::heat_explicit`, `heat_implicit`, `crank_nicolson`, plus the `Tridiag` solve in `dsa/tridiag.h`.

# %%
import sys; from pathlib import Path
for so in Path('../build').rglob('nmpy*.so'):
    sys.path.insert(0, str(so.parent)); break
import nmpy
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# TODO: drive `nmpy.pde.crank_nicolson(...)` over a grid in $\xi$, transform back, plot the price surface, overlay the closed-form curve.
